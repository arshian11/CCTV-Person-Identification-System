# %%
import insightface

app = insightface.app.FaceAnalysis(name="buffalo_l")
app.prepare(ctx_id=0)

print(app.models.keys())
print(app.models["recognition"].input_shape)
# Out:
# c:\Users\ACER\anaconda3\envs\faceid\Lib\site-packages\onnxruntime\capi\onnxruntime_inference_collection.py:115: UserWarning: Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'AzureExecutionProvider, CPUExecutionProvider'
#   warnings.warn(
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\ACER/.insightface\models\buffalo_l\1k3d68.onnx landmark_3d_68 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\ACER/.insightface\models\buffalo_l\2d106det.onnx landmark_2d_106 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\ACER/.insightface\models\buffalo_l\det_10g.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# ...

# %%
from recognizer.extractor import get_arcface_embedding
import cv2
import numpy as np

img1 = cv2.imread("dataset/augmented_faces/arsh_raza/aug_1.jpg")
img2 = cv2.imread("dataset/augmented_faces/arsh_raza/aug_2.jpg")

e1 = np.load("datasets/npy_augmented_embeddings/arsh_raza/IMG20251112213207_aug1.npy")
e2 = np.load("datasets/npy_augmented_embeddings/arsh_raza/IMG20251112213207_aug2.npy")

dist = np.sum((e1 - e2)**2)**0.5
similarity = 1 / (1 + dist)

print("distance:", dist)
print("similarity:", similarity)
# Out:
# distance: 0.7269332104086451
# similarity: 0.5790611900754226

# %%
np.linalg.norm(e1)
# Out:
# 1.0

# %%
e1.shape
# Out:
# (512,)

# %%
# %pip help insightface

# %%
# !python -m detectors.person_detector
# Out:
# Loading Person Model...
# Loading Face Model...
# --- FRAME STATS (Total: 7.9460s) ---
# 1. Capture:      0.8237s
# 2. Person Detect:4.0659s
# 3. Box Merge:    0.0020s
# 4. Face Detect:  2.9903s [Count: 0]
# 5. Recognition:  0.0000s
# 6. Viz/Draw:     0.0641s
# ------------------------------
# --- FRAME STATS (Total: 1.5483s) ---
# 1. Capture:      0.0110s
# 2. Person Detect:0.9904s
# 3. Box Merge:    0.0000s
# 4. Face Detect:  0.5460s [Count: 0]
# 5. Recognition:  0.0000s
# 6. Viz/Draw:     0.0010s
# ------------------------------
# --- FRAME STATS (Total: 1.4097s) ---
# 1. Capture:      0.0030s
# 2. Person Detect:0.8702s
# 3. Box Merge:    0.0000s
# 4. Face Detect:  0.5359s [Count: 0]
# 5. Recognition:  0.0000s
# 6. Viz/Draw:     0.0005s
# ------------------------------
# --- FRAME STATS (Total: 1.2192s) ---
# 1. Capture:      0.0155s
# 2. Person Detect:0.8359s
# 3. Box Merge:    0.0000s
# 4. Face Detect:  0.3677s [Count: 0]
# 5. Recognition:  0.0000s
# 6. Viz/Draw:     0.0000s
# ...
